# %%
#CLICK FILE UPLOAD NOTEBOOK AND CLICK GITHUB AND PASTE JUPYTER LINK

# %%
# !git clone https://github.com/niazwazir/SRCNN-Keras.git

# %%
# !ls
# Out:
# sample_data  SRCNN-Keras

# %%
cd SRCNN-Keras
# Out:
# /content/SRCNN-Keras

# %%
# !unzip yang91.zip
# Out:
# Archive:  yang91.zip
#    creating: yang91/
#   inflating: yang91/tt9.bmp
#   inflating: yang91/tt8.bmp
#   inflating: yang91/tt7.bmp
#   inflating: yang91/tt6.bmp
#   inflating: yang91/tt5.bmp
#   inflating: yang91/tt4.bmp
#   inflating: yang91/tt3.bmp
#   inflating: yang91/tt27.bmp
#   inflating: yang91/tt26.bmp
#   inflating: yang91/tt25.bmp
#   inflating: yang91/tt24.bmp
#   inflating: yang91/tt23.bmp
#   inflating: yang91/tt22.bmp
#   inflating: yang91/tt21.bmp
#   inflating: yang91/tt20.bmp
#   inflating: yang91/tt2.bmp
#   inflating: yang91/tt19.bmp
#   inflating: yang91/tt18.bmp
#   inflating: yang91/tt17.bmp
#   inflating: yang91/tt16.bmp
#   inflating: yang91/tt15.bmp
#   inflating: yang91/tt14.bmp
#   inflating: yang91/tt13.bmp
#   inflating: yang91/tt12.bmp
#   inflating: yang91/tt10.bmp
#   inflating: yang91/tt1.bmp
#   inflating: yang91/t66.bmp
#   inflating: yang91/t65.bmp
#   inflating: yang91/t64.bmp
#   inflating: yang91/t63.bmp
#   inflating: yang91/t62.bmp
#   inflating: yang91/t61.bmp
#   inflating: yang91/t60.bmp
#   inflating: yang91/t59.bmp
#   inflating: yang91/t58.bmp
#   inflating: yang91/t57.bmp
#   inflating: yang91/t56.bmp
#   inflating: yang91/t55.bmp
#   inflating: yang91/t54.bmp
#   inflating: yang91/t53.bmp
#   inflating: yang91/t52.bmp
#   inflating: yang91/t51.bmp
#   inflating: yang91/t50.bmp
#   inflating: yang91/t49.bmp
#   inflating: yang91/t48.bmp
#   inflating: yang91/t47.bmp
#   inflating: yang91/t46.bmp
#   inflating: yang91/t45.bmp
#   inflating: yang91/t44.bmp
#   inflating: yang91/t43.bmp
#   inflating: yang91/t42.bmp
#   inflating: yang91/t40.bmp
#   inflating: yang91/t39.bmp
#   inflating: yang91/t38.bmp
#   inflating: yang91/t37.bmp
#   inflating: yang91/t36.bmp
#   inflating: yang91/t35.bmp
#   inflating: yang91/t34.bmp
#   inflating: yang91/t33.bmp
#   inflating: yang91/t32.bmp
#   inflating: yang91/t31.bmp
#   inflating: yang91/t30.bmp
#   inflating: yang91/t29.bmp

# %%
import keras.backend as K
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Activation, Input
from keras import optimizers
from keras.models import load_model
import numpy as np
import scipy.misc
import scipy.ndimage
import cv2
import math
import glob
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
img_shape = (32,32,1)
input_img = Input(shape=(img_shape))
C1 = Conv2D(64,(9,9),padding='SAME',name='CONV1')(input_img)
A1 = Activation('relu', name='act1')(C1)
C2 = Conv2D(32,(1,1),padding='SAME',name='CONV2')(A1)
A2 = Activation('relu', name='act2')(C2)
C3 = Conv2D(1,(5,5),padding='SAME',name='CONV3')(A2)
A3 = Activation('relu', name='act3')(C3)
model = Model(input_img, A3)
opt = optimizers.Adam(lr=0.0003)
model.compile(optimizer=opt,loss='mean_squared_error')
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32, 32, 1)         0
# _________________________________________________________________
# CONV1 (Conv2D)               (None, 32, 32, 64)        5248
# _________________________________________________________________
# act1 (Activation)            (None, 32, 32, 64)        0
# _________________________________________________________________
# CONV2 (Conv2D)               (None, 32, 32, 32)        2080
# _________________________________________________________________
# act2 (Activation)            (None, 32, 32, 32)        0
# _________________________________________________________________
# CONV3 (Conv2D)               (None, 32, 32, 1)         801
# _________________________________________________________________
# act3 (Activation)            (None, 32, 32, 1)         0
# =================================================================
# Total params: 8,129
# Trainable params: 8,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
def modcrop(image, scale=2): #BY DEFAULT SCALE 2
    if len(image.shape) == 3:
        h, w, _ = image.shape
        h = h - np.mod(h, scale)
        w = w - np.mod(w, scale)
        image = image[0:h, 0:w, :]
    else:
        h, w = image.shape
        h = h - np.mod(h, scale)
        w = w - np.mod(w, scale)
        image = image[0:h, 0:w]
    return image

# %%
def create_LR(image,scale):
    label_ = modcrop(image, scale)
    label_ = label_ / 255.
    input_ = scipy.ndimage.interpolation.zoom(label_, (1./scale), prefilter=False)
    input_ = scipy.ndimage.interpolation.zoom(input_, (scale/1.), prefilter=False)
    return input_

# %%
path = 'yang91/'
files_y = glob.glob(path + '*.*')
trainfiles = files_y[:60]             #HERE TOTAL IMAGES ARE 91 , SO FROM 91 up to 85 used for Training
valfiles = files_y[60:]               #HERE Above 85 used for Validation Set
img_size = 32
stride = 16
X_train = []
Y_train = []
X_val = []
Y_val = []

# %%
# Extract patch image for training
for file_y in trainfiles:
    tmp_y = scipy.misc.imread(file_y,flatten=True, mode='YCbCr').astype(np.float)
    tmp_X = create_LR(tmp_y,2) #############################################################SCALE###########
    h,w = tmp_y.shape
    for x in range(0, h-img_size+1, stride):
        for y in range(0, w-img_size+1, stride):
            sub_input = tmp_X[x:x+img_size,y:y+img_size].reshape(img_size,img_size,1)
            sub_label = tmp_y[x:x+img_size, y:y+img_size].reshape(img_size,img_size,1)
            X_train.append(sub_input)
            Y_train.append(sub_label)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
# Extract patch image for validation
for file_y in valfiles:
    tmp_y = scipy.misc.imread(file_y,flatten=True, mode='YCbCr').astype(np.float)
    tmp_X = create_LR(tmp_y,2)###########################################################SCALE################
    h,w = tmp_y.shape
    for x in range(0, h-img_size+1, stride):
        for y in range(0, w-img_size+1, stride):
            sub_input = tmp_X[x:x+img_size,  y:y+img_size].reshape(img_size,img_size,1) # [32 x 32]
            sub_label = tmp_y[x:x+img_size, y:y+img_size].reshape(img_size,img_size,1) # [32 x 32]
            X_val.append(sub_input)
            Y_val.append(sub_label)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_val = np.array(X_val)
Y_val = np.array(Y_val)

# %%
LEARN_RATE = 1.0e-4

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam, SGD

# %%
checkpoint = ModelCheckpoint('best_model_improved.h5',  # model filename

                             monitor='val_loss', # quantity to monitor

                             verbose=0, # verbosity - 0 or 1

                             save_best_only= True, # The latest best model will not be overwritten

                             mode='auto') # The decision to overwrite model is made 

                                          # automatically depending on the quantity to monitor

# %%
model.compile(loss='mse', # Better loss function for neural networks
              optimizer=Adam(lr=LEARN_RATE), # Adam optimizer with 1.0e-4 learning rate
              metrics = ['accuracy']) # Metrics to be evaluated by the model

# %%
model_details = model.fit(X_train, Y_train,
                    batch_size = 128,
                    epochs = 200, # number of iterations
                    validation_data= (X_val, Y_val),
                    callbacks=[checkpoint],
                    verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 14478 samples, validate on 586 samples
# Epoch 1/200
# 14478/14478 [==============================] - 6s 383us/step - loss: 16661.6307 - acc: 3.2181e-04 - val_loss: 12438.0112 - val_acc: 0.0010
# Epoch 2/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 12701.6953 - acc: 1.2816e-04 - val_loss: 6585.9137 - val_acc: 2.0831e-04
# Epoch 3/200
# 14478/14478 [==============================] - 1s 73us/step - loss: 4250.9459 - acc: 1.7241e-04 - val_loss: 1439.5774 - val_acc: 1.3165e-04
# Epoch 4/200
# 14478/14478 [==============================] - 1s 73us/step - loss: 1575.0701 - acc: 2.8174e-04 - val_loss: 1246.6601 - val_acc: 1.1665e-04
# Epoch 5/200
# 14478/14478 [==============================] - 1s 73us/step - loss: 1511.4719 - acc: 2.5719e-04 - val_loss: 1218.3288 - val_acc: 8.1658e-05
# Epoch 6/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 1464.0713 - acc: 2.6117e-04 - val_loss: 1171.0207 - val_acc: 9.3323e-05
# Epoch 7/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 1393.7249 - acc: 2.6326e-04 - val_loss: 1108.2034 - val_acc: 7.1659e-05
# Epoch 8/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 1303.8445 - acc: 2.5874e-04 - val_loss: 1029.0533 - val_acc: 1.6832e-04
# Epoch 9/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 1187.3170 - acc: 2.6414e-04 - val_loss: 926.0804 - val_acc: 1.5998e-04
# Epoch 10/200
# 14478/14478 [==============================] - 1s 73us/step - loss: 1043.8343 - acc: 2.7055e-04 - val_loss: 806.6961 - val_acc: 2.3331e-04
# Epoch 11/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 889.8698 - acc: 2.8053e-04 - val_loss: 687.5372 - val_acc: 3.4330e-04
# Epoch 12/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 748.9481 - acc: 3.3395e-04 - val_loss: 590.0538 - val_acc: 2.6997e-04
# Epoch 13/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 643.0618 - acc: 4.5503e-04 - val_loss: 522.6190 - val_acc: 2.2664e-04
# Epoch 14/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 581.2632 - acc: 5.8285e-04 - val_loss: 487.0022 - val_acc: 1.6165e-04
# Epoch 15/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 547.4872 - acc: 6.6844e-04 - val_loss: 464.7083 - val_acc: 1.9165e-04
# Epoch 16/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 522.5991 - acc: 6.8895e-04 - val_loss: 445.1164 - val_acc: 2.6830e-04
# Epoch 17/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 498.3947 - acc: 7.0109e-04 - val_loss: 424.8130 - val_acc: 3.1497e-04
# Epoch 18/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 471.7550 - acc: 7.2241e-04 - val_loss: 402.1012 - val_acc: 3.8163e-04
# Epoch 19/200
# 14478/14478 [==============================] - 1s 73us/step - loss: 442.2877 - acc: 7.5107e-04 - val_loss: 377.6466 - val_acc: 4.3495e-04
# Epoch 20/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 410.9340 - acc: 8.0422e-04 - val_loss: 351.9254 - val_acc: 4.9661e-04
# Epoch 21/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 376.3211 - acc: 8.5947e-04 - val_loss: 322.6094 - val_acc: 6.3827e-04
# Epoch 22/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 340.9579 - acc: 9.1086e-04 - val_loss: 296.1703 - val_acc: 9.6323e-04
# Epoch 23/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 310.6420 - acc: 9.6564e-04 - val_loss: 274.6851 - val_acc: 0.0013
# Epoch 24/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 286.8377 - acc: 0.0010 - val_loss: 258.6785 - val_acc: 0.0012
# Epoch 25/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 269.2646 - acc: 0.0011 - val_loss: 247.2724 - val_acc: 0.0010
# Epoch 26/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 256.4758 - acc: 0.0012 - val_loss: 238.9143 - val_acc: 0.0011
# Epoch 27/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 246.9728 - acc: 0.0012 - val_loss: 232.3726 - val_acc: 0.0012
# Epoch 28/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 239.5456 - acc: 0.0012 - val_loss: 227.1252 - val_acc: 0.0013
# Epoch 29/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 232.5841 - acc: 0.0013 - val_loss: 221.1113 - val_acc: 0.0013
# Epoch 30/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 225.3495 - acc: 0.0013 - val_loss: 215.1075 - val_acc: 0.0013
# Epoch 31/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 219.4655 - acc: 0.0014 - val_loss: 210.2431 - val_acc: 0.0014
# Epoch 32/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 213.9631 - acc: 0.0014 - val_loss: 205.7215 - val_acc: 0.0014
# Epoch 33/200
# 14478/14478 [==============================] - 1s 73us/step - loss: 208.8217 - acc: 0.0014 - val_loss: 201.4020 - val_acc: 0.0014
# Epoch 34/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 204.3661 - acc: 0.0015 - val_loss: 197.7044 - val_acc: 0.0013
# Epoch 35/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 200.5385 - acc: 0.0015 - val_loss: 194.4444 - val_acc: 0.0014
# Epoch 36/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 196.9360 - acc: 0.0015 - val_loss: 191.5107 - val_acc: 0.0015
# Epoch 37/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 193.5280 - acc: 0.0015 - val_loss: 188.4977 - val_acc: 0.0014
# Epoch 38/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 190.5040 - acc: 0.0016 - val_loss: 185.9742 - val_acc: 0.0014
# Epoch 39/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 187.7295 - acc: 0.0016 - val_loss: 183.4530 - val_acc: 0.0015
# Epoch 40/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 185.0588 - acc: 0.0016 - val_loss: 181.0738 - val_acc: 0.0015
# Epoch 41/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 182.5987 - acc: 0.0016 - val_loss: 179.0346 - val_acc: 0.0015
# Epoch 42/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 180.4577 - acc: 0.0017 - val_loss: 177.0693 - val_acc: 0.0015
# Epoch 43/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 178.4597 - acc: 0.0017 - val_loss: 175.3652 - val_acc: 0.0016
# Epoch 44/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 176.6719 - acc: 0.0017 - val_loss: 173.9551 - val_acc: 0.0015
# Epoch 45/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 175.0052 - acc: 0.0017 - val_loss: 172.3276 - val_acc: 0.0016
# Epoch 46/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 173.4839 - acc: 0.0017 - val_loss: 170.9780 - val_acc: 0.0016
# Epoch 47/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 172.0157 - acc: 0.0017 - val_loss: 169.7202 - val_acc: 0.0016
# Epoch 48/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 170.6668 - acc: 0.0017 - val_loss: 168.5231 - val_acc: 0.0016
# Epoch 49/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 169.3777 - acc: 0.0017 - val_loss: 167.3892 - val_acc: 0.0017
# Epoch 50/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 168.1645 - acc: 0.0017 - val_loss: 166.4680 - val_acc: 0.0017
# Epoch 51/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 167.0043 - acc: 0.0017 - val_loss: 165.3140 - val_acc: 0.0017
# Epoch 52/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 165.8679 - acc: 0.0018 - val_loss: 164.3054 - val_acc: 0.0016
# Epoch 53/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 164.7839 - acc: 0.0018 - val_loss: 163.3477 - val_acc: 0.0017
# Epoch 54/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 163.7128 - acc: 0.0018 - val_loss: 162.4830 - val_acc: 0.0017
# Epoch 55/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 162.6671 - acc: 0.0018 - val_loss: 161.4809 - val_acc: 0.0017
# Epoch 56/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 161.6120 - acc: 0.0018 - val_loss: 160.5760 - val_acc: 0.0017
# Epoch 57/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 160.5692 - acc: 0.0018 - val_loss: 159.6612 - val_acc: 0.0017
# Epoch 58/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 159.5134 - acc: 0.0018 - val_loss: 158.7116 - val_acc: 0.0017
# Epoch 59/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 158.4433 - acc: 0.0018 - val_loss: 157.8190 - val_acc: 0.0017
# Epoch 60/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 157.3792 - acc: 0.0018 - val_loss: 156.9008 - val_acc: 0.0017
# Epoch 61/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 156.3289 - acc: 0.0018 - val_loss: 156.0676 - val_acc: 0.0018
# Epoch 62/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 155.2833 - acc: 0.0018 - val_loss: 155.1609 - val_acc: 0.0017
# Epoch 63/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 154.1918 - acc: 0.0018 - val_loss: 154.1533 - val_acc: 0.0017
# Epoch 64/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 153.1048 - acc: 0.0018 - val_loss: 153.2812 - val_acc: 0.0018
# Epoch 65/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 152.0042 - acc: 0.0018 - val_loss: 152.3798 - val_acc: 0.0017
# Epoch 66/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 150.9113 - acc: 0.0019 - val_loss: 151.3932 - val_acc: 0.0018
# Epoch 67/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 149.8260 - acc: 0.0019 - val_loss: 150.5085 - val_acc: 0.0017
# Epoch 68/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 148.7626 - acc: 0.0019 - val_loss: 149.5980 - val_acc: 0.0017
# Epoch 69/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 147.6951 - acc: 0.0019 - val_loss: 148.7218 - val_acc: 0.0017
# Epoch 70/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 146.6703 - acc: 0.0019 - val_loss: 147.8606 - val_acc: 0.0017
# Epoch 71/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 145.6297 - acc: 0.0019 - val_loss: 147.0102 - val_acc: 0.0017
# Epoch 72/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 144.6242 - acc: 0.0019 - val_loss: 146.2008 - val_acc: 0.0017
# Epoch 73/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 143.6169 - acc: 0.0019 - val_loss: 145.3101 - val_acc: 0.0017
# Epoch 74/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 142.6169 - acc: 0.0019 - val_loss: 144.4671 - val_acc: 0.0018
# Epoch 75/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 141.6327 - acc: 0.0019 - val_loss: 143.6647 - val_acc: 0.0018
# Epoch 76/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 140.6137 - acc: 0.0019 - val_loss: 142.7806 - val_acc: 0.0018
# Epoch 77/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 139.5508 - acc: 0.0019 - val_loss: 141.9588 - val_acc: 0.0018
# Epoch 78/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 138.4751 - acc: 0.0020 - val_loss: 140.9425 - val_acc: 0.0018
# Epoch 79/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 137.4166 - acc: 0.0020 - val_loss: 140.0500 - val_acc: 0.0018
# Epoch 80/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 136.3814 - acc: 0.0020 - val_loss: 139.1803 - val_acc: 0.0018
# Epoch 81/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 135.3750 - acc: 0.0020 - val_loss: 138.4013 - val_acc: 0.0018
# Epoch 82/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 134.4069 - acc: 0.0020 - val_loss: 137.5224 - val_acc: 0.0018
# Epoch 83/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 133.4458 - acc: 0.0020 - val_loss: 136.7702 - val_acc: 0.0018
# Epoch 84/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 132.5329 - acc: 0.0020 - val_loss: 135.9679 - val_acc: 0.0018
# Epoch 85/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 131.6370 - acc: 0.0021 - val_loss: 135.2155 - val_acc: 0.0019
# Epoch 86/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 130.7614 - acc: 0.0021 - val_loss: 134.4591 - val_acc: 0.0019
# Epoch 87/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 129.9104 - acc: 0.0021 - val_loss: 133.7365 - val_acc: 0.0020
# Epoch 88/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 129.0640 - acc: 0.0021 - val_loss: 133.0006 - val_acc: 0.0019
# Epoch 89/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 128.1661 - acc: 0.0021 - val_loss: 132.2363 - val_acc: 0.0020
# Epoch 90/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 127.2808 - acc: 0.0021 - val_loss: 131.5376 - val_acc: 0.0019
# Epoch 91/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 126.4360 - acc: 0.0021 - val_loss: 130.7974 - val_acc: 0.0019
# Epoch 92/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 125.6235 - acc: 0.0021 - val_loss: 130.1654 - val_acc: 0.0020
# Epoch 93/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 124.8484 - acc: 0.0022 - val_loss: 129.4750 - val_acc: 0.0020
# Epoch 94/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 124.0983 - acc: 0.0022 - val_loss: 128.8284 - val_acc: 0.0020
# Epoch 95/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 123.3733 - acc: 0.0022 - val_loss: 128.2148 - val_acc: 0.0021
# Epoch 96/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 122.6594 - acc: 0.0022 - val_loss: 127.8429 - val_acc: 0.0021
# Epoch 97/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 121.9890 - acc: 0.0022 - val_loss: 127.0247 - val_acc: 0.0021
# Epoch 98/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 121.3224 - acc: 0.0022 - val_loss: 126.4743 - val_acc: 0.0021
# Epoch 99/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 120.6699 - acc: 0.0022 - val_loss: 125.9373 - val_acc: 0.0022
# Epoch 100/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 120.0361 - acc: 0.0022 - val_loss: 125.3787 - val_acc: 0.0022
# Epoch 101/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 119.4165 - acc: 0.0022 - val_loss: 124.8931 - val_acc: 0.0023
# Epoch 102/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 118.8105 - acc: 0.0022 - val_loss: 124.3136 - val_acc: 0.0022
# Epoch 103/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 118.2075 - acc: 0.0022 - val_loss: 123.8871 - val_acc: 0.0022
# Epoch 104/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 117.6249 - acc: 0.0022 - val_loss: 123.2711 - val_acc: 0.0022
# Epoch 105/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 117.0347 - acc: 0.0022 - val_loss: 122.7602 - val_acc: 0.0023
# Epoch 106/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 116.4687 - acc: 0.0023 - val_loss: 122.2853 - val_acc: 0.0023
# Epoch 107/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 115.9072 - acc: 0.0023 - val_loss: 121.7778 - val_acc: 0.0022
# Epoch 108/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 115.3564 - acc: 0.0023 - val_loss: 121.3340 - val_acc: 0.0023
# Epoch 109/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 114.8211 - acc: 0.0023 - val_loss: 120.8070 - val_acc: 0.0022
# Epoch 110/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 114.3152 - acc: 0.0023 - val_loss: 120.4298 - val_acc: 0.0021
# Epoch 111/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 113.8128 - acc: 0.0023 - val_loss: 119.9249 - val_acc: 0.0022
# Epoch 112/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 113.3345 - acc: 0.0023 - val_loss: 119.4892 - val_acc: 0.0023
# Epoch 113/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 112.8714 - acc: 0.0023 - val_loss: 119.0664 - val_acc: 0.0023
# Epoch 114/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 112.4138 - acc: 0.0023 - val_loss: 118.6735 - val_acc: 0.0023
# Epoch 115/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 111.9734 - acc: 0.0023 - val_loss: 118.2439 - val_acc: 0.0022
# Epoch 116/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 111.5388 - acc: 0.0023 - val_loss: 117.8520 - val_acc: 0.0022
# Epoch 117/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 111.1024 - acc: 0.0023 - val_loss: 117.4575 - val_acc: 0.0023
# Epoch 118/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 110.6841 - acc: 0.0023 - val_loss: 117.0614 - val_acc: 0.0022
# Epoch 119/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 110.2808 - acc: 0.0023 - val_loss: 116.6851 - val_acc: 0.0023
# Epoch 120/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 109.8660 - acc: 0.0023 - val_loss: 116.3010 - val_acc: 0.0022
# Epoch 121/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 109.4752 - acc: 0.0024 - val_loss: 115.9805 - val_acc: 0.0022
# Epoch 122/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 109.0923 - acc: 0.0024 - val_loss: 115.6147 - val_acc: 0.0022
# Epoch 123/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 108.7303 - acc: 0.0024 - val_loss: 115.2604 - val_acc: 0.0022
# Epoch 124/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 108.3600 - acc: 0.0024 - val_loss: 114.9106 - val_acc: 0.0023
# Epoch 125/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 108.0139 - acc: 0.0024 - val_loss: 114.5871 - val_acc: 0.0022
# Epoch 126/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 107.6708 - acc: 0.0024 - val_loss: 114.2786 - val_acc: 0.0023
# Epoch 127/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 107.3350 - acc: 0.0024 - val_loss: 113.9568 - val_acc: 0.0022
# Epoch 128/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 107.0123 - acc: 0.0024 - val_loss: 113.6486 - val_acc: 0.0023
# Epoch 129/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 106.6854 - acc: 0.0024 - val_loss: 113.3431 - val_acc: 0.0022
# Epoch 130/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 106.3739 - acc: 0.0024 - val_loss: 113.0887 - val_acc: 0.0022
# Epoch 131/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 106.0655 - acc: 0.0024 - val_loss: 112.7617 - val_acc: 0.0022
# Epoch 132/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 105.7662 - acc: 0.0024 - val_loss: 112.4613 - val_acc: 0.0023
# Epoch 133/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 105.4722 - acc: 0.0025 - val_loss: 112.1796 - val_acc: 0.0023
# Epoch 134/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 105.1780 - acc: 0.0025 - val_loss: 111.9074 - val_acc: 0.0022
# Epoch 135/200
# 14478/14478 [==============================] - 1s 77us/step - loss: 104.8897 - acc: 0.0025 - val_loss: 111.6706 - val_acc: 0.0023
# Epoch 136/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 104.6046 - acc: 0.0025 - val_loss: 111.3574 - val_acc: 0.0023
# Epoch 137/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 104.3188 - acc: 0.0025 - val_loss: 111.0885 - val_acc: 0.0023
# Epoch 138/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 104.0390 - acc: 0.0025 - val_loss: 110.8363 - val_acc: 0.0023
# Epoch 139/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 103.7612 - acc: 0.0025 - val_loss: 110.6048 - val_acc: 0.0023
# Epoch 140/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 103.4877 - acc: 0.0025 - val_loss: 110.2968 - val_acc: 0.0023
# Epoch 141/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 103.2239 - acc: 0.0025 - val_loss: 110.0271 - val_acc: 0.0023
# Epoch 142/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 102.9474 - acc: 0.0025 - val_loss: 109.7882 - val_acc: 0.0023
# Epoch 143/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 102.6885 - acc: 0.0025 - val_loss: 109.5507 - val_acc: 0.0023
# Epoch 144/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 102.4372 - acc: 0.0025 - val_loss: 109.2883 - val_acc: 0.0023
# Epoch 145/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 102.1773 - acc: 0.0025 - val_loss: 109.0743 - val_acc: 0.0024
# Epoch 146/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 101.9310 - acc: 0.0025 - val_loss: 108.8597 - val_acc: 0.0023
# Epoch 147/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 101.6854 - acc: 0.0025 - val_loss: 108.6425 - val_acc: 0.0024
# Epoch 148/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 101.4442 - acc: 0.0025 - val_loss: 108.3517 - val_acc: 0.0024
# Epoch 149/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 101.2209 - acc: 0.0025 - val_loss: 108.1521 - val_acc: 0.0024
# Epoch 150/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 100.9883 - acc: 0.0025 - val_loss: 107.9259 - val_acc: 0.0024
# Epoch 151/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 100.7621 - acc: 0.0025 - val_loss: 107.7053 - val_acc: 0.0024
# Epoch 152/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 100.5424 - acc: 0.0026 - val_loss: 107.4958 - val_acc: 0.0023
# Epoch 153/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 100.3290 - acc: 0.0026 - val_loss: 107.3399 - val_acc: 0.0023
# Epoch 154/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 100.1249 - acc: 0.0026 - val_loss: 107.0988 - val_acc: 0.0024
# Epoch 155/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 99.9106 - acc: 0.0026 - val_loss: 106.8945 - val_acc: 0.0024
# Epoch 156/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 99.7041 - acc: 0.0026 - val_loss: 106.7162 - val_acc: 0.0024
# Epoch 157/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 99.5086 - acc: 0.0026 - val_loss: 106.5010 - val_acc: 0.0024
# Epoch 158/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 99.3061 - acc: 0.0026 - val_loss: 106.3129 - val_acc: 0.0024
# Epoch 159/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 99.1015 - acc: 0.0026 - val_loss: 106.1649 - val_acc: 0.0024
# Epoch 160/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 98.9027 - acc: 0.0026 - val_loss: 105.9167 - val_acc: 0.0024
# Epoch 161/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 98.7044 - acc: 0.0026 - val_loss: 105.7775 - val_acc: 0.0024
# Epoch 162/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 98.5132 - acc: 0.0026 - val_loss: 105.5325 - val_acc: 0.0024
# Epoch 163/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 98.3154 - acc: 0.0026 - val_loss: 105.3506 - val_acc: 0.0024
# Epoch 164/200
# 14478/14478 [==============================] - 1s 79us/step - loss: 98.1229 - acc: 0.0026 - val_loss: 105.2007 - val_acc: 0.0024
# Epoch 165/200
# 14478/14478 [==============================] - 1s 79us/step - loss: 97.9377 - acc: 0.0026 - val_loss: 105.0030 - val_acc: 0.0024
# Epoch 166/200
# 14478/14478 [==============================] - 1s 80us/step - loss: 97.7496 - acc: 0.0026 - val_loss: 104.7960 - val_acc: 0.0024
# Epoch 167/200
# 14478/14478 [==============================] - 1s 80us/step - loss: 97.5491 - acc: 0.0027 - val_loss: 104.6022 - val_acc: 0.0024
# Epoch 168/200
# 14478/14478 [==============================] - 1s 79us/step - loss: 97.3631 - acc: 0.0027 - val_loss: 104.4202 - val_acc: 0.0024
# Epoch 169/200
# 14478/14478 [==============================] - 1s 79us/step - loss: 97.1763 - acc: 0.0027 - val_loss: 104.2354 - val_acc: 0.0024
# Epoch 170/200
# 14478/14478 [==============================] - 1s 80us/step - loss: 96.9920 - acc: 0.0027 - val_loss: 104.0775 - val_acc: 0.0024
# Epoch 171/200
# 14478/14478 [==============================] - 1s 80us/step - loss: 96.8119 - acc: 0.0027 - val_loss: 103.8896 - val_acc: 0.0025
# Epoch 172/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 96.6318 - acc: 0.0027 - val_loss: 103.7163 - val_acc: 0.0025
# Epoch 173/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 96.4467 - acc: 0.0027 - val_loss: 103.5366 - val_acc: 0.0025
# Epoch 174/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 96.2628 - acc: 0.0027 - val_loss: 103.3864 - val_acc: 0.0025
# Epoch 175/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 96.0823 - acc: 0.0027 - val_loss: 103.1999 - val_acc: 0.0025
# Epoch 176/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 95.9077 - acc: 0.0027 - val_loss: 103.0244 - val_acc: 0.0025
# Epoch 177/200
# 14478/14478 [==============================] - 1s 74us/step - loss: 95.7329 - acc: 0.0027 - val_loss: 102.8566 - val_acc: 0.0025
# Epoch 178/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 95.5576 - acc: 0.0027 - val_loss: 102.7259 - val_acc: 0.0025
# Epoch 179/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 95.3906 - acc: 0.0027 - val_loss: 102.5218 - val_acc: 0.0025
# Epoch 180/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 95.2265 - acc: 0.0027 - val_loss: 102.3655 - val_acc: 0.0025
# Epoch 181/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 95.0582 - acc: 0.0027 - val_loss: 102.1945 - val_acc: 0.0026
# Epoch 182/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 94.8980 - acc: 0.0027 - val_loss: 102.1197 - val_acc: 0.0026
# Epoch 183/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 94.7436 - acc: 0.0027 - val_loss: 101.9830 - val_acc: 0.0026
# Epoch 184/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 94.5843 - acc: 0.0027 - val_loss: 101.7462 - val_acc: 0.0026
# Epoch 185/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 94.4317 - acc: 0.0027 - val_loss: 101.6219 - val_acc: 0.0025
# Epoch 186/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 94.2900 - acc: 0.0027 - val_loss: 101.5115 - val_acc: 0.0026
# Epoch 187/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 94.1382 - acc: 0.0027 - val_loss: 101.3226 - val_acc: 0.0026
# Epoch 188/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.9917 - acc: 0.0028 - val_loss: 101.1696 - val_acc: 0.0026
# Epoch 189/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.8519 - acc: 0.0027 - val_loss: 101.0591 - val_acc: 0.0025
# Epoch 190/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.7176 - acc: 0.0028 - val_loss: 100.9496 - val_acc: 0.0026
# Epoch 191/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.5745 - acc: 0.0028 - val_loss: 100.7696 - val_acc: 0.0026
# Epoch 192/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.4345 - acc: 0.0028 - val_loss: 100.7247 - val_acc: 0.0026
# Epoch 193/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.3029 - acc: 0.0028 - val_loss: 100.5114 - val_acc: 0.0026
# Epoch 194/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.1658 - acc: 0.0028 - val_loss: 100.4223 - val_acc: 0.0026
# Epoch 195/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 93.0414 - acc: 0.0028 - val_loss: 100.2588 - val_acc: 0.0026
# Epoch 196/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 92.9027 - acc: 0.0028 - val_loss: 100.1194 - val_acc: 0.0026
# Epoch 197/200
# 14478/14478 [==============================] - 1s 75us/step - loss: 92.7717 - acc: 0.0028 - val_loss: 100.0891 - val_acc: 0.0026
# Epoch 198/200
# 14478/14478 [==============================] - 1s 76us/step - loss: 92.6526 - acc: 0.0028 - val_loss: 99.8836 - val_acc: 0.0026
# Epoch 199/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 92.5197 - acc: 0.0028 - val_loss: 99.7935 - val_acc: 0.0026
# Epoch 200/200
# 14478/14478 [==============================] - 1s 78us/step - loss: 92.3955 - acc: 0.0028 - val_loss: 99.6547 - val_acc: 0.0027

# %%
scores = model.evaluate(X_val, Y_val, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 0.27%

# %%
model.save('wscale2.h5')

# %%
img_o = scipy.misc.imread('baby_x2_GT.png',flatten=True,mode='YCbCr').astype(np.float)
img = create_LR(img_o,2) #################################################################SCALE#################
img_size = 32
stride = 16
h,w = img.shape
piece_wise = []
for x in range(0, h-img_size+1, stride):
    for y in range (0, w-img_size+1, stride):
        sub_input = img[x:x+img_size, y:y+img_size].reshape(img_size,img_size,1)
        piece_wise.append(sub_input)
input_ = np.asarray(piece_wise)
srcnn = load_model('wscale2.h5')
hat = srcnn.predict(input_)
img_re = np.zeros(img.shape)
i = 0
for x in range(0, h-img_size+1, stride):
    for y in range (0, w-img_size+1, stride):
        img_re[x:x+img_size, y:y+img_size] = hat[i].reshape(img_size,img_size)
        i += 1
cv2.imwrite('restored1.bmp', img_re)
cv2.imwrite('HR1.bmp', img_o)
img_save = (img*255).astype(np.uint8)
cv2.imwrite('blurred1.bmp',img_save)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# True

# %%
#CALCULATE PSNR
original = cv2.imread("HR1.bmp")
LR       = cv2.imread("blurred1.bmp")
contrast = cv2.imread("restored1.bmp",1)
def psnr(img1, img2):
    mse = np.mean((img1-img2)**2)
    if mse ==0:
        return 100
    PIXEL_MAX = 255.0
    return 20* math.log10(PIXEL_MAX / math.sqrt(mse))
d = psnr(original,contrast)
print(d)
# Out:
# 36.209208434

# %%
fig = plt.figure(figsize = (14,14), dpi = 100)
ax = plt.subplot("131")
ax.imshow(original)
ax.set_title("GT")
plt.grid(0)

ax = plt.subplot("132")
ax.imshow(LR)
ax.set_title("blurred_Image")
plt.grid(0)

ax = plt.subplot("133")
ax.imshow(contrast)
ax.set_title("HR_RECONSTRUCTED")
plt.grid(0)
plt.show()
